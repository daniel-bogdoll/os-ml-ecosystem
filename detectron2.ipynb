# %% [markdown]
# <img src="https://dl.fbaipublicfiles.com/detectron2/Detectron2-Logo-Horz.png" width="500">
#
# "Detectron2 is a platform for object detection, segmentation and other visual recognition tasks." (by Facebook Research)
#
# --> successor of Detectron and [maskrcnn-benchmark](https://github.com/facebookresearch/maskrcnn-benchmark/)
#
# LICENSE: Apache-2.0
# GITHUB: https://github.com/facebookresearch/detectron2

# %% [markdown]
# ## Some traing benchmark results tested (only) 5 years ago

# %%
# %%html
# <iframe src="https://detectron2.readthedocs.io/en/latest/notes/benchmarks.html#main-results" width="1200" height="370"></iframe>

# %% [markdown]
# Best times are over ...
#
# ![image.png](attachment:c9724f79-de93-4568-85f8-6f59d682ee63.png)

# %% [markdown]
# ## (annoying) Dependencies
# Latest pre-built version v0.6 (Oct. 2021) requires
# ```
# torch '1.10'
# CUDA '11.3'
# ```
#
# Highest torch version when building from source seems to be (at least for me):
# ```
# torch '1.13.1+cu117'
# torchvision '0.14.1+cu117'
# (Python 3.10.12)
# ```

# %% [markdown]
# ## Why bring it up then?
#
# - back when I started using, it was the fastest/most efficient for fine-tuning (that I've tested)
# - nowadays, a lot of (FSOD) projects still build on top of **detectron2**
# - they use the training, evaluation, dataset, augmentation, transforms utils provided by **detectron2**
# - if you need a docker for detectron2 at some point, I might be able to help

# %% [markdown]
# ## Code example (pretrained inference & fine-tuning)
# https://colab.research.google.com/drive/16jcaJoc6bCFAQ96jDe2HwtXj7BMD_-m5#scrollTo=7d3KxiHO_0gb
